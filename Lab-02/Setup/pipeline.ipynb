# %%
import pandas as pd

df = pd.read_csv('https://s3.amazonaws.com/shelterdata/shelter1000.csv')

df.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk   05/08/2019 6:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo   07/18/2018 4:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose   02/13/2016 5:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby

# %%
#df = df.drop_duplicates(subset=['Animal ID'])

# %%
df['Color'].str.split('/').to_list()
# Out:
# [['Brown Tabby', 'White'],
#  ['White', 'Brown'],
#  ['Gray'],
#  ['Buff'],
#  ['Orange Tabby'],
#  ['Brown'],
#  ['White', 'Brown'],
#  ['Brown Tabby'],
#  ['Black'],
#  ['White', 'Orange Tabby'],
#  ['Black', 'White'],
#  ['Black'],
#  ['Blue', 'White'],
#  ['White', 'Blue'],
#  ['Black', 'White'],
#  ['Brown Tabby'],
#  ['Brown Tabby'],
#  ['Red', 'White'],
#  ['Black', 'White'],
#  ['Orange Tabby'],
#  ['Orange Tabby'],
#  ['Torbie'],
#  ['Brown Tabby'],
#  ['Brown', 'Black'],
#  ['Gray'],
#  ['Blue'],
#  ['Calico'],
#  ['Tricolor'],
#  ['Lilac Point'],
#  ['Brown', 'Black'],
#  ['White', 'Tan'],
#  ['Brown Tabby'],
#  ['White'],
#  ['Orange Tabby'],
#  ['Brown'],
#  ['Brown'],
#  ['Black', 'White'],
#  ['Brown', 'White'],
#  ['Brown', 'White'],
#  ['Black', 'White'],
#  ['Brown'],
#  ['Gray'],
#  ['Brown Brindle', 'White'],
#  ['Brown', 'Black'],
#  ['Orange Tabby'],
#  ['Black', 'White'],
#  ['White', 'Brown'],
#  ['Brown', 'Black'],
#  ['Black', 'Brown'],
#  ['Tan', 'White'],
#  ['Chocolate', 'White'],
#  ['Red'],
#  ['Black', 'Tan'],
#  ['White', 'White'],
#  ['Brown', 'Black'],
#  ['Black', 'White'],
#  ['Black', 'Brown'],
#  ['Blue Tick', 'Black'],
#  ['Black', 'White'],
#  ['Blue', 'White'],
#  ['Brown Brindle', 'White'],
#  ['White', 'Black'],
#  ['Black', 'White'],
#  ['Gray', 'Black'],
#  ['Tortie'],
#  ['Tan'],
#  ['White', 'Blue Tabby'],
#  ['Sable', 'Tan'],
#  ['Fawn', 'Tan'],
#  ['Brown', 'Black'],
#  ['Tan', 'White'],
#  ['White'],
#  ['Brown Brindle'],
#  ['Brown', 'Brown'],
#  ['Brown Brindle', 'White'],
#  ['Brown', 'White'],
#  ['Tricolor'],
#  ['Black', 'Gray'],
#  ['Blue'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Black'],
#  ['Cream Tabby'],
#  ['Brown'],
#  ['Black'],
#  ['White'],
#  ['Brown', 'White'],
#  ['Black', 'White'],
#  ['Brown', 'White'],
#  ['Brown', 'Black'],
#  ['White', 'Black'],
#  ['Brown Tabby'],
#  ['Black', 'Brown'],
#  ['Red', 'White'],
#  ['Brown Tabby'],
#  ['Brown Brindle', 'White'],
#  ['Gray', 'White'],
#  ['Black'],
#  ['Tortie'],
#  ['Brown', 'Gray'],
#  ['Brown Brindle', 'White'],
#  ['Black'],
#  ['Red'],
#  ['Blue Tabby', 'White'],
#  ['Brown Tabby'],
#  ['Red', 'White'],
#  ['Orange Tabby', 'White'],
#  ['Blue Merle'],
#  ['Orange Tabby', 'White'],
#  ['Orange Tabby'],
#  ['Brown Merle', 'White'],
#  ['Orange Tabby', 'White'],
#  ['Blue Tabby', 'White'],
#  ['Silver'],
#  ['Brown', 'White'],
#  ['Red', 'White'],
#  ['Brown Tabby', 'White'],
#  ['Brown', 'Black'],
#  ['Tricolor'],
#  ['Cream', 'Brown'],
#  ['Apricot'],
#  ['Apricot', 'Brown'],
#  ['Brown', 'White'],
#  ['Silver'],
#  ['White'],
#  ['Black', 'White'],
#  ['Black', 'Tan'],
#  ['Brown', 'White'],
#  ['Black', 'Tan'],
#  ['Blue'],
#  ['Tan', 'White'],
#  ['Tortie Point'],
#  ['Brown Tabby', 'White'],
#  ['Tan', 'Black'],
#  ['Seal Point'],
#  ['Black', 'Tan'],
#  ['Seal Point'],
#  ['Black'],
#  ['Torbie', 'Brown Tabby'],
#  ['Fawn', 'White'],
#  ['Brown', 'White'],
#  ['White', 'Black'],
#  ['Tan', 'Black'],
#  ['Blue Tabby'],
#  ['Brown Brindle', 'White'],
#  ['Blue Tick'],
#  ['Tricolor', 'White'],
#  ['White', 'Gray'],
#  ['Black'],
#  ['Brown Brindle', 'White'],
#  ['Brown'],
#  ['Tan', 'White'],
#  ['Black', 'White'],
#  ['Black', 'Tricolor'],
#  ['Chocolate', 'Tan'],
#  ['Brown Brindle', 'White'],
#  ['White', 'Brown'],
#  ['White', 'Brown Tabby'],
#  ['Black', 'Tan'],
#  ['Brown Tabby'],
#  ['Brown Tabby', 'White'],
#  ['Tortie'],
#  ['Brown'],
#  ['White', 'Brown Brindle'],
#  ['Lynx Point'],
#  ['Buff'],
#  ['Brown Tabby', 'White'],
#  ['Torbie'],
#  ['Brown Brindle', 'White'],
#  ['Brown', 'Black'],
#  ['Green'],
#  ['Brown Tabby'],
#  ['Brown Tabby'],
#  ['White', 'Buff'],
#  ['Brown Brindle'],
#  ['Red', 'White'],
#  ['Torbie'],
#  ['Black'],
#  ['Cream Tabby'],
#  ['Cream'],
#  ['Black', 'Tricolor'],
#  ['Black', 'Brown'],
#  ['White', 'Blue'],
#  ['Cream'],
#  ['Orange Tabby'],
#  ['Red', 'White'],
#  ['White', 'Black'],
#  ['Blue'],
#  ['Brown Tabby'],
#  ['Blue Tick'],
#  ['Black', 'Tan'],
#  ['Orange Tabby', 'White'],
#  ['Tortie'],
#  ['Brown'],
#  ['Black', 'White'],
#  ['White', 'Tan'],
#  ['Black', 'Tan'],
#  ['Torbie'],
#  ['Tricolor'],
#  ['Blue', 'White'],
#  ['Tan'],
#  ['Cream'],
#  ['Black', 'Brown'],
#  ['Black', 'White'],
#  ['Black', 'Tan'],
#  ['Tortie'],
#  ['Black', 'White'],
#  ['Blue', 'Tan'],
#  ['Black'],
#  ['White'],
#  ['Red', 'White'],
#  ['Black', 'White'],
#  ['Black', 'White'],
#  ['White', 'Brown Tabby'],
#  ['Blue'],
#  ['Orange Tabby'],
#  ['Blue'],
#  ['Brown Tabby'],
#  ['Brown Brindle', 'White'],
#  ['Black Brindle', 'White'],
#  ['Sable'],
#  ['Red'],
#  ['Yellow'],
#  ['Orange Tabby', 'White'],
#  ['Black', 'Yellow Brindle'],
#  ['White', 'Black'],
#  ['Blue Tabby', 'White'],
#  ['White', 'Brown Tabby'],
#  ['Chocolate', 'Black'],
#  ['Black', 'Tan'],
#  ['Black', 'Red'],
#  ['Brown Tabby'],
#  ['Fawn', 'White'],
#  ['Black', 'White'],
#  ['Tan', 'White'],
#  ['White', 'Brown'],
#  ['Orange Tabby'],
#  ['Black', 'White'],
#  ['Black'],
#  ['Black'],
#  ['Black'],
#  ['Tricolor'],
#  ['White'],
#  ['Black'],
#  ['Brown', 'Black'],
#  ['Black', 'White'],
#  ['Tan'],
#  ['Torbie'],
#  ['Blue', 'White'],
#  ['Tan', 'White'],
#  ['Black'],
#  ['Orange Tabby', 'White'],
#  ['Brown', 'Black'],
#  ['Chocolate'],
#  ['Calico'],
#  ['White', 'Brown Tabby'],
#  ['Tan', 'White'],
#  ['Buff'],
#  ['Black'],
#  ['Tricolor'],
#  ['Brown'],
#  ['Brown', 'Black'],
#  ['Blue', 'Brown Brindle'],
#  ['Brown Tabby', 'White'],
#  ['Tan', 'White'],
#  ['Blue Tabby'],
#  ['Cream'],
#  ['Black', 'White'],
#  ['Brown', 'Black'],
#  ['Black', 'White'],
#  ['Brown Tabby'],
#  ['White', 'Black'],
#  ['Black', 'White'],
#  ['Brown'],
#  ['White', 'Black'],
#  ['Tan'],
#  ['Orange Tabby'],
#  ['Orange Tabby'],
#  ['Tricolor'],
#  ['Black', 'White'],
#  ['Tan'],
#  ['Cream Tabby', 'White'],
#  ['Tortie'],
#  ['Tan', 'Gray'],
#  ['Black', 'White'],
#  ['Tricolor'],
#  ['Black', 'Brown'],
#  ['Black'],
#  ['White', 'Black'],
#  ['Brown Tabby'],
#  ['Brown', 'White'],
#  ['Brown', 'Black'],
#  ['Chocolate', 'White'],
#  ['Tan', 'Black'],
#  ['Brown Tabby'],
#  ['White'],
#  ['Brown Tabby', 'White'],
#  ['Apricot'],
#  ['Black'],
#  ['Black', 'Brown'],
#  ['Brown Tabby', 'White'],
#  ['Blue', 'White'],
#  ['White', 'Blue Tabby'],
#  ['Black', 'White'],
#  ['Black'],
#  ['Black'],
#  ['White', 'Tan'],
#  ['Tan', 'White'],
#  ['Brown', 'Black'],
#  ['Cream Tabby', 'White'],
#  ['White', 'Black'],
#  ['Brown'],
#  ['Brown Tabby', 'White'],
#  ['Black'],
#  ['Sable'],
#  ['Tan'],
#  ['Tortie Point'],
#  ['Tan'],
#  ['Tricolor'],
#  ['Black'],
#  ['Brown', 'White'],
#  ['White', 'Black'],
#  ['Black', 'White'],
#  ['Black', 'White'],
#  ['Blue Tick'],
#  ['Blue Tick'],
#  ['Brown Tabby', 'White'],
#  ['Black'],
#  ['Brown'],
#  ['Brown Tabby', 'White'],
#  ['Brown'],
#  ['Brown', 'White'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Tricolor'],
#  ['Black'],
#  ['Tan', 'Black'],
#  ['Brown Tabby'],
#  ['Black', 'Brown'],
#  ['Brown Brindle', 'White'],
#  ['Brown Tabby'],
#  ['Brown Tabby', 'White'],
#  ['Brown'],
#  ['Brown'],
#  ['Chocolate', 'White'],
#  ['Black', 'White'],
#  ['Red', 'White'],
#  ['Red', 'Buff'],
#  ['Tan'],
#  ['Black', 'Tan'],
#  ['Black', 'Brown'],
#  ['Orange Tabby'],
#  ['Cream Tabby'],
#  ['Tan'],
#  ['Black'],
#  ['Blue Tabby'],
#  ['Black', 'White'],
#  ['Blue Merle'],
#  ['Yellow Brindle', 'White'],
#  ['White', 'Gray'],
#  ['Lynx Point'],
#  ['Brown Tabby'],
#  ['Black'],
#  ['Chocolate'],
#  ['Lynx Point', 'White'],
#  ['Tortie'],
#  ['Orange Tabby'],
#  ['Tricolor'],
#  ['Black', 'Brown'],
#  ['Calico'],
#  ['Tan', 'Black'],
#  ['Orange Tabby'],
#  ['Brown', 'White'],
#  ['Chocolate Point'],
#  ['Yellow'],
#  ['Blue Smoke'],
#  ['Tricolor'],
#  ['Tricolor'],
#  ['Chocolate', 'White'],
#  ['Brown Tabby'],
#  ['Brown Brindle', 'White'],
#  ['White'],
#  ['White', 'Brown'],
#  ['Gray', 'Black'],
#  ['Tan', 'White'],
#  ['Chocolate', 'Tan'],
#  ['Black'],
#  ['Tan', 'Black'],
#  ['Black', 'Brown Brindle'],
#  ['Tricolor'],
#  ['Brown Tabby', 'White'],
#  ['Yellow'],
#  ['Black', 'White'],
#  ['Tan', 'White'],
#  ['Brown'],
#  ['Black', 'Tan'],
#  ['Brown', 'White'],
#  ['Black'],
#  ['Blue', 'White'],
#  ['White', 'Tan'],
#  ['White', 'Tan'],
#  ['Tan', 'White'],
#  ['Lynx Point'],
#  ['Black', 'Brown'],
#  ['Orange Tabby'],
#  ['Brown Tabby'],
#  ['Black', 'White'],
#  ['Brown Tabby'],
#  ['Brown'],
#  ['Brown Tabby'],
#  ['Brown Tabby'],
#  ['Tricolor'],
#  ['Black', 'Tan'],
#  ['Brown', 'Tan'],
#  ['Orange Tabby'],
#  ['Silver Tabby'],
#  ['Gray Tabby'],
#  ['White', 'Black'],
#  ['Calico'],
#  ['White', 'Brown Tabby'],
#  ['White', 'Tan'],
#  ['Torbie'],
#  ['Orange Tabby'],
#  ['Tan', 'White'],
#  ['Orange Tabby'],
#  ['Brown Brindle'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Brown Tabby'],
#  ['Black'],
#  ['Orange Tabby'],
#  ['Black', 'Brown'],
#  ['Tricolor'],
#  ['Blue', 'White'],
#  ['Tan', 'Black'],
#  ['Brown', 'White'],
#  ['White', 'Red'],
#  ['Cream'],
#  ['Brown'],
#  ['White', 'Black'],
#  ['Sable'],
#  ['Torbie'],
#  ['Brown Tabby'],
#  ['Red', 'White'],
#  ['Blue', 'White'],
#  ['Sable', 'Cream'],
#  ['Brown', 'White'],
#  ['Blue', 'White'],
#  ['Brown', 'White'],
#  ['Black'],
#  ['Black'],
#  ['Brown'],
#  ['Black Brindle', 'White'],
#  ['Brown Tabby', 'White'],
#  ['Black', 'White'],
#  ['Brown', 'Orange'],
#  ['Black'],
#  ['Calico'],
#  ['Red', 'White'],
#  ['Fawn', 'White'],
#  ['Black'],
#  ['White'],
#  ['Brown Tabby', 'White'],
#  ['Blue', 'White'],
#  ['Brown'],
#  ['Brown Tabby'],
#  ['Red', 'White'],
#  ['Gray', 'Black'],
#  ['White', 'Brown Tabby'],
#  ['Black', 'White'],
#  ['Black Brindle'],
#  ['Blue Tabby', 'White'],
#  ['Brown', 'Black'],
#  ['Black', 'Tan'],
#  ['Black', 'White'],
#  ['Brown Tabby'],
#  ['White'],
#  ['Blue', 'White'],
#  ['Black', 'White'],
#  ['Red', 'White'],
#  ['Blue', 'White'],
#  ['Brown Brindle'],
#  ['White', 'White'],
#  ['White', 'Tan'],
#  ['Black'],
#  ['Brown Tabby'],
#  ['Chocolate', 'White'],
#  ['White'],
#  ['Tricolor', 'White'],
#  ['Sable', 'Black'],
#  ['Tan'],
#  ['Brown'],
#  ['Blue'],
#  ['Brown', 'Black'],
#  ['Black', 'White'],
#  ['Calico'],
#  ['Gray', 'White'],
#  ['Orange', 'White'],
#  ['Brown Tabby'],
#  ['Black', 'White'],
#  ['Brown Brindle', 'Black'],
#  ['Tan'],
#  ['Black', 'White'],
#  ['Brown Tiger', 'Brown'],
#  ['Black', 'White'],
#  ['Black', 'White'],
#  ['Black'],
#  ['Blue Tabby', 'White'],
#  ['Tan'],
#  ['Black'],
#  ['Tan'],
#  ['Tan'],
#  ['Brown Tabby'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Chocolate'],
#  ['Brown Tabby'],
#  ['White', 'White'],
#  ['Torbie'],
#  ['Seal Point', 'White'],
#  ['Chocolate', 'White'],
#  ['Black', 'Tan'],
#  ['Sable', 'Black'],
#  ['Red', 'White'],
#  ['Blue', 'White'],
#  ['Blue Tabby'],
#  ['Brown Tabby'],
#  ['White', 'Brown Brindle'],
#  ['Brown Tabby', 'Black'],
#  ['Brown'],
#  ['Brown Brindle'],
#  ['Brown'],
#  ['Red'],
#  ['Calico'],
#  ['Buff'],
#  ['White'],
#  ['Tortie'],
#  ['Black'],
#  ['Orange Tabby'],
#  ['White', 'Brown Brindle'],
#  ['Black', 'White'],
#  ['Orange Tabby', 'White'],
#  ['Brown', 'White'],
#  ['White'],
#  ['Tricolor'],
#  ['White', 'Tan'],
#  ['Blue', 'White'],
#  ['White', 'Brown Tabby'],
#  ['Black'],
#  ['Tan'],
#  ['Tan', 'White'],
#  ['Black', 'Brown'],
#  ['Torbie', 'White'],
#  ['Brown Brindle', 'White'],
#  ['Brown Tabby', 'White'],
#  ['Tan'],
#  ['Red'],
#  ['Brown', 'Brown'],
#  ['Black', 'Tan'],
#  ['Tricolor'],
#  ['Cream Tabby', 'White'],
#  ['Tan'],
#  ['Black'],
#  ['Calico'],
#  ['Yellow Brindle'],
#  ['White', 'Brown'],
#  ['Black'],
#  ['Black', 'Tan'],
#  ['Brown Tabby', 'White'],
#  ['Black', 'White'],
#  ['Tricolor'],
#  ['Brown Brindle'],
#  ['Black', 'White'],
#  ['Cream', 'White'],
#  ['Brown Tabby', 'White'],
#  ['White'],
#  ['Black', 'White'],
#  ['Brown Tabby', 'White'],
#  ['Black', 'Brown'],
#  ['Black'],
#  ['Brown Tabby', 'White'],
#  ['Black'],
#  ['Blue', 'White'],
#  ['Black', 'White'],
#  ['White', 'Orange Tabby'],
#  ['Black'],
#  ['Black'],
#  ['Brown Brindle', 'Black'],
#  ['Calico'],
#  ['Black'],
#  ['Buff'],
#  ['Black', 'White'],
#  ['Black', 'Chocolate'],
#  ['Gray', 'Black'],
#  ['Tan', 'White'],
#  ['Brown'],
#  ['Brown Tabby'],
#  ['Tricolor'],
#  ['Gold', 'White'],
#  ['White', 'Brown'],
#  ['Gray', 'White'],
#  ['White', 'Brown'],
#  ['Gray', 'Black'],
#  ['White', 'Cream Tabby'],
#  ['Brown Tabby', 'White'],
#  ['Tricolor'],
#  ['Brown Brindle'],
#  ['Brown Brindle', 'White'],
#  ['Tan', 'White'],
#  ['White'],
#  ['Brown Tabby', 'White'],
#  ['Black', 'Tan'],
#  ['White', 'Brown Brindle'],
#  ['Red', 'Black'],
#  ['Blue', 'White'],
#  ['Brown Tabby'],
#  ['Black'],
#  ['Brown'],
#  ['Brown Tabby', 'White'],
#  ['Brown Tabby'],
#  ['Brown', 'White'],
#  ['Blue'],
#  ['Tan', 'White'],
#  ['Black'],
#  ['Tortie'],
#  ['Black', 'White'],
#  ['Black'],
#  ['White'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Tricolor'],
#  ['Tan'],
#  ['Blue', 'White'],
#  ['Tricolor'],
#  ['Calico'],
#  ['Blue', 'White'],
#  ['Brown Tabby'],
#  ['Black', 'White'],
#  ['Blue'],
#  ['Brown'],
#  ['Brown'],
#  ['Tan', 'Black'],
#  ['Black', 'White'],
#  ['Brown Brindle'],
#  ['Brown Tabby'],
#  ['Lynx Point'],
#  ['Torbie'],
#  ['Tan', 'Black'],
#  ['Red', 'Tan'],
#  ['White', 'Gray'],
#  ['Tan', 'Black'],
#  ['Brown', 'White'],
#  ['Brown Tabby'],
#  ['Black', 'White'],
#  ['Tan'],
#  ['Black', 'White'],
#  ['Black', 'White'],
#  ['Tan'],
#  ['White', 'Tan'],
#  ['White', 'Orange'],
#  ['Cream Tabby', 'White'],
#  ['Black', 'White'],
#  ['Buff'],
#  ['Cream'],
#  ['Black Brindle', 'White'],
#  ['Black', 'Tan'],
#  ['Blue Tabby', 'White'],
#  ['Brown'],
#  ['Black Tabby'],
#  ['Black', 'White'],
#  ['Gray'],
#  ['Tricolor', 'Brown'],
#  ['Brown Tabby'],
#  ['White'],
#  ['Tricolor'],
#  ['Tan', 'White'],
#  ['Cream', 'White'],
#  ['Black', 'Tan'],
#  ['Tortie'],
#  ['Black'],
#  ['Brown Tabby', 'White'],
#  ['Blue', 'White'],
#  ['Black', 'White'],
#  ['Orange Tabby'],
#  ['Seal Point', 'Gray'],
#  ['White'],
#  ['Tan', 'Black'],
#  ['Black', 'White'],
#  ['Torbie', 'White'],
#  ['Black'],
#  ['White', 'Tricolor'],
#  ['Tricolor'],
#  ['White', 'Tan'],
#  ['Silver', 'Tan'],
#  ['White', 'Tan'],
#  ['Tan', 'White'],
#  ['Brown Tabby', 'White'],
#  ['Gray'],
#  ['Brown', 'White'],
#  ['Brown Tabby'],
#  ['Tan'],
#  ['Cream'],
#  ['Brown Tabby'],
#  ['Brown'],
#  ['Brown Tabby'],
#  ['Gray Tabby', 'White'],
#  ['Brown Tabby', 'White'],
#  ['Brown', 'White'],
#  ['Orange Tabby', 'White'],
#  ['Orange Tabby'],
#  ['Orange Tabby', 'White'],
#  ['Blue', 'White'],
#  ['Blue Tabby'],
#  ['Black Brindle'],
#  ['Brown Tabby', 'White'],
#  ['Red'],
#  ['Brown', 'Tricolor'],
#  ['Blue Tabby'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Gray', 'White'],
#  ['Blue', 'White'],
#  ['Black'],
#  ['Blue'],
#  ['Black'],
#  ['White'],
#  ['White', 'Black'],
#  ['Brown Tabby'],
#  ['Black Tabby', 'White'],
#  ['Brown'],
#  ['Brown Brindle', 'White'],
#  ['Black'],
#  ['Brown Tabby', 'White'],
#  ['Blue', 'White'],
#  ['Brown', 'Tan'],
#  ['White', 'Tricolor'],
#  ['Black'],
#  ['Tan'],
#  ['Yellow', 'White'],
#  ['White', 'Red Tick'],
#  ['Cream Tabby', 'White'],
#  ['Blue'],
#  ['Tricolor'],
#  ['Calico'],
#  ['Brown Brindle', 'White'],
#  ['Tan', 'White'],
#  ['Gray', 'White'],
#  ['Fawn'],
#  ['Tortie'],
#  ['Brown Tabby'],
#  ['Tan', 'White'],
#  ['Brown Tabby', 'White'],
#  ['Chocolate', 'White'],
#  ['Black'],
#  ['Black'],
#  ['Brown Tabby', 'White'],
#  ['Blue', 'White'],
#  ['White', 'Brown'],
#  ['Brown'],
#  ['Tan', 'White'],
#  ['Blue'],
#  ['Black'],
#  ['Brown Tabby'],
#  ['White', 'Tan'],
#  ['Black'],
#  ['Tan', 'White'],
#  ['Red'],
#  ['Gray Tabby', 'White'],
#  ['Black', 'White'],
#  ['Black'],
#  ['Orange Tabby', 'White'],
#  ['Blue', 'White'],
#  ['Orange Tabby'],
#  ['Cream', 'Black'],
#  ['Buff'],
#  ['Black', 'Tan'],
#  ['Brown'],
#  ['Orange Tabby', 'White'],
#  ['Brown Tabby'],
#  ['Brown Tabby'],
#  ['Brown'],
#  ['Tricolor'],
#  ['Brown Tabby'],
#  ['Blue', 'White'],
#  ['Black'],
#  ['Cream Tabby'],
#  ['Black'],
#  ['Brown', 'Black'],
#  ['Cream Tabby', 'White'],
#  ['Black'],
#  ['Tan', 'Black'],
#  ['Brown', 'White'],
#  ['Torbie'],
#  ['Blue', 'White'],
#  ['Gray', 'Tortie'],
#  ['White', 'Brown Tabby'],
#  ['Brown', 'White'],
#  ['Brown'],
#  ['White', 'Black'],
#  ['Tan', 'White'],
#  ['Orange Tabby', 'White'],
#  ['Black'],
#  ['Tan', 'White'],
#  ['Black'],
#  ['Torbie'],
#  ['Black', 'Red'],
#  ['Black', 'White'],
#  ['Black', 'White'],
#  ['Black', 'Brown'],
#  ['White', 'Black'],
#  ['Black', 'Tan'],
#  ['Black'],
#  ['Tan'],
#  ['Flame Point'],
#  ['Black', 'Brown'],
#  ['Brown Tabby'],
#  ['White', 'Brown'],
#  ['Blue', 'White'],
#  ['White'],
#  ['Sable', 'White'],
#  ['Red', 'White'],
#  ['Brown', 'Brown'],
#  ['Brown Tabby'],
#  ['Tan', 'White'],
#  ['Tricolor', 'White'],
#  ['Blue', 'White'],
#  ['Orange Tabby', 'White'],
#  ['Black', 'White'],
#  ['Tan', 'White'],
#  ['Gray', 'White'],
#  ['White', 'Buff'],
#  ['Chocolate', 'White'],
#  ['Brown', 'White'],
#  ['Brown', 'White'],
#  ['Black', 'Tricolor'],
#  ['Black'],
#  ['Tan'],
#  ['White'],
#  ['Fawn'],
#  ['Blue'],
#  ['Black', 'White'],
#  ['Seal Point'],
#  ['Blue', 'White'],
#  ['Chocolate', 'White'],
#  ['Chocolate Point'],
#  ['Gray', 'Black'],
#  ['Black', 'White'],
#  ['Tan', 'White'],
#  ['Red', 'Tan'],
#  ['White'],
#  ['Brown Tabby'],
#  ['Black', 'Brown'],
#  ['White', 'Orange'],
#  ['Gray', 'Tan'],
#  ['Black', 'White'],
#  ['Blue'],
#  ['Brown', 'White'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Black', 'White'],
#  ['Black', 'White'],
#  ['Brown'],
#  ['Tan', 'White'],
#  ['Brown Tabby', 'White'],
#  ['Brown Brindle', 'White'],
#  ['Brown', 'Tan'],
#  ['White', 'Brown'],
#  ['Tan', 'Black'],
#  ['Blue'],
#  ['White', 'Black'],
#  ['Brown Tabby', 'White'],
#  ['Brown Tabby'],
#  ['Blue', 'White'],
#  ['Black'],
#  ['Orange Tabby'],
#  ['Blue', 'White'],
#  ['Cream'],
#  ['Fawn', 'White'],
#  ['Black', 'White'],
#  ['Tortie'],
#  ['Red', 'White'],
#  ['Black', 'Tan'],
#  ['Torbie'],
#  ['Brown Tabby'],
#  ['Gray'],
#  ['Brown Tabby'],
#  ['Black'],
#  ['Tan'],
#  ['Black'],
#  ['Tricolor'],
#  ['Black', 'Tan'],
#  ['Blue', 'White'],
#  ['Brown Tabby'],
#  ['White'],
#  ['Brown Brindle', 'White'],
#  ['Fawn'],
#  ['Black', 'Brown'],
#  ['Black', 'White'],
#  ['Brown'],
#  ['Red', 'White'],
#  ['Lynx Point'],
#  ['Tortie'],
#  ['Brown Tabby', 'White'],
#  ['Orange Tabby'],
#  ['Black'],
#  ['Brown Tabby'],
#  ['Black', 'White'],
#  ['Black'],
#  ['Blue Tabby'],
#  ['Black'],
#  ['White', 'Brown'],
#  ['Black', 'White'],
#  ['Brown'],
#  ['Brown', 'White'],
#  ['Brown Brindle', 'White'],
#  ['Orange Tabby', 'White'],
#  ['Blue', 'White'],
#  ['Black', 'White'],
#  ['Seal Point', 'White'],
#  ['Black'],
#  ['White'],
#  ['Black'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Brown', 'White'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Tortie'],
#  ['Gray', 'Tan'],
#  ['Brown'],
#  ['Brown Tabby'],
#  ['Blue Tabby'],
#  ['Brown Tabby', 'White'],
#  ['Fawn'],
#  ['White', 'Gray'],
#  ['Fawn', 'Black'],
#  ['Brown Tabby', 'White'],
#  ['Calico'],
#  ['Black', 'White'],
#  ['Brown Brindle', 'White'],
#  ['Black'],
#  ['White'],
#  ['Brown Tabby', 'White'],
#  ['Black', 'White'],
#  ['White', 'Tan'],
#  ['Black'],
#  ['Calico Point', 'Gray'],
#  ['Black', 'White'],
#  ['Black', 'Black'],
#  ['Black', 'White'],
#  ['Red'],
#  ['Orange Tabby', 'White'],
#  ['Brown Brindle'],
#  ['White', 'Black'],
#  ['Brown Tabby'],
#  ['White', 'Black'],
#  ['Brown'],
#  ['Tricolor'],
#  ['Sable'],
#  ['Blue Tabby'],
#  ['Black', 'White'],
#  ['Tan'],
#  ['Calico'],
#  ['White', 'Brown Tabby'],
#  ['Cream Tabby', 'White'],
#  ['Chocolate', 'White'],
#  ['Black', 'Tan'],
#  ['Black'],
#  ['Black', 'White'],
#  ['Blue Tabby'],
#  ['Black'],
#  ['Tortie'],
#  ['White'],
#  ['Brown Tabby'],
#  ['Torbie'],
#  ['Black'],
#  ['Calico'],
#  ['Red', 'Cream'],
#  ['Black'],
#  ['Brown', 'White'],
#  ['Blue Tabby', 'White'],
#  ['Black'],
#  ['White', 'Tan'],
#  ['Black', 'White'],
#  ['White', 'Brown Brindle'],
#  ['White', 'Brown'],
#  ['Brown Tabby'],
#  ['Black', 'Gray'],
#  ['Tortie'],
#  ['Tricolor'],
#  ['Chocolate', 'White'],
#  ['Black', 'White'],
#  ['Calico'],
#  ['Black', 'Brown'],
#  ['Fawn', 'White'],
#  ['Black', 'White'],
#  ['Black', 'White'],
#  ['Brown'],
#  ['Black', 'White'],
#  ['Brown', 'White']]

# %%
df['Outcome Type'].unique()
# Out:
# array(['Rto-Adopt', 'Adoption', 'Euthanasia', 'Transfer',
#        'Return to Owner', 'Died', 'Disposal'], dtype=object)

# %%
df['Outcome Subtype'].unique()
#df[df['Outcome Subtype'] == 'Aggressive']
# Out:
# array([nan, 'Partner', 'Foster', 'SCRP', 'Out State', 'Suffering',
#        'Underage', 'Snr', 'Rabies Risk', 'In Kennel', 'Offsite',
#        'Aggressive', 'Enroute', 'Emergency', 'Field', 'At Vet'],
#       dtype=object)

# %%
df[df['Outcome Subtype'] == 'Partner']['Outcome Type'].unique()
# Out:
# array(['Transfer'], dtype=object)

# %%
df[df['Animal ID'] == 'A664941']
# Out:
#     Animal ID     Name               DateTime MonthYear Date of Birth  \
# 93    A664941  Tequila  10/12/2013 6:14:00 PM  Oct 2013    10/11/2009
# 458   A664941  Tequila  05/29/2017 4:04:00 PM  May 2017    10/11/2009
#
#         Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 93   Return to Owner             NaN         Dog    Spayed Female
# 458         Adoption             NaN         Dog    Spayed Female
#
#     Age upon Outcome         Breed      Color
# 93           4 years  Pit Bull Mix  Red/White
# 458          7 years  Pit Bull Mix  Red/White

# %%
df[['month', 'year']] = df.MonthYear.str.split(' ', expand=True)

# %%
df.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk   05/08/2019 6:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo   07/18/2018 4:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose   02/13/2016 5:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color month  year
# 0              Domestic Shorthair Mix  Brown Tabby/White   May  2019
# 1             Chihuahua Shorthair Mix        White/Brown   Jul  2018
# 2                             Raccoon               Gray   Aug  2020
# 3  Anatol Shepherd/Labrador Retriever               Buff   Feb  2016
# 4              Domestic Shorthair Mix       Orange Tabby   Mar  2014

# %%
import numpy as np
df['sex'] = df['Sex upon Outcome'].replace('Unknown', np.nan)
df.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk   05/08/2019 6:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo   07/18/2018 4:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose   02/13/2016 5:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color month  year  \
# 0              Domestic Shorthair Mix  Brown Tabby/White   May  2019
# 1             Chihuahua Shorthair Mix        White/Brown   Jul  2018
# 2                             Raccoon               Gray   Aug  2020
# 3  Anatol Shepherd/Labrador Retriever               Buff   Feb  2016
# 4              Domestic Shorthair Mix       Orange Tabby   Mar  2014
#
#              sex
# 0  Neutered Male
# 1  Neutered Male
# 2            NaN
# 3  Neutered Male
# 4    Intact Male

# %%
df.drop(columns = ['MonthYear', 'Sex upon Outcome'], inplace=True)

# %%
df.to_csv('processed_data.csv')
